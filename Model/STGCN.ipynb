# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('../Data/reshaped_dengue_data.csv')

df= df.to_numpy()

# remove dates column
df = df[:,1:]
print(df.shape)
# Out:
# (228, 558)

# %%
location= 123
plt.figure()
plt.plot(range(0,228),df[:,location]) 
plt.show()
